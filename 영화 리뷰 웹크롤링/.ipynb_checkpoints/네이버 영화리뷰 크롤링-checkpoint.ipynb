# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://movie.naver.com/movie/bi/mi/review.naver?code=192608"
res = requests.get(url)

# %%
res.text
# Out:
# '\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\t\r\n\t\r\n\t\t\r\n\t\t\r\n\t\t\t\r\n\t\t\t\t\t\t\r\n\t\t\t\r\n\t\t\t\t\r\n\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\r\n\t\t\t\t \r\n\t\t\t\r\n\t\t\r\n\t\t\r\n\t\t\t\r\n\t\t\r\n\t\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n<meta charset="utf-8">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta http-equiv="imagetoolbar" content="no">\r\n<title>범죄도시2 : 네이버 영화</title>\r\n\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\t\r\n\t\t\r\n\t\r\n\r\n\r\n\r\n<meta property="me2:image" content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg"/>\r\n<meta property="me2:post_tag" content="네이버영화 범죄도시2"/>\r\n<meta property="me2:category1" content="네이버영화"/>\r\n<meta property="me2:category2" content="범죄도시2"/>\r\n\r\n\r\n\r\n\t\r\n\t\r\n\t\r\n\t\t<meta property="og:title" content="범죄도시2"/>\r\n\t\r\n\r\n\r\n<meta property="og:type" content="article"/>\r\n\r\n<meta property="og:url" content="https://movie.naver.com/movie/bi/mi/review.naver?code=192608"/>\r\n\r\n\r\n\t\r\n\t\t<meta property="og:image" content="https://movie-phinf.pstatic.net/20220516_144/1652665409592Chvey_JPEG/movie_image.jpg?type=m665_443_2"/>\r\n\t\r\n\t\r\n\r\n\r\n\t\r\n\t<meta property="og:description" content="가리봉동 소탕작전 후 4년 뒤,금천서 강력반은 베트남으로 도주한 용의자를 인도받아 오라는 미션을 받..."/>\r\n\r\n\r\n\r\n<meta property="og:article:thumbnailUrl" content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg"/>\r\n<meta property="og:article:author" content="네이버 영화"/>\r\n<meta property="og:article:author:url" content="https://movie.naver.com/"/>\r\n\r\n\n\n\n\t\n\t\n\t\n\t\n\t\t<link rel="shortcut icon" href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" type="image/x-icon">\n\t\t\t\n\n\r\n\n<link rel="stylesheet" type="text/css" href="/css/deploy/movie.all.css?20220613155138" />\r\n\n\n\n<script type="text/javascript" src="/js/deploy/movie.all.js?20220613155138"></script>\n\n\n\r\n</head>\r\n<body >\r\n<div id="wrap" class="basic">\r\n\r\n\t<!-- GNB -->\r\n\t\n\n\n\n<script type="text/javascript">\nfunction delayed_submit(object) {\n\tif (navigator.userAgent.indexOf(\'MSIE\') == -1) {\n\t\tvar b = c = new Date();\n      \twhile ((b.getTime() - c.getTime()) < 100) {\n\t\t\tb = new Date();\n      \t}\n\t} \n}\n</script>\n\n<script type="text/javascript">\n\tvar gnb_service = "movie";\n\tvar gnb_logout = "https://movie.naver.com/movie/bi/mi/review.naver%3Fcode%3D192608";\n\tvar gnb_template = "gnb_utf8";\n\tvar gnb_brightness=3;\n\tvar gnb_response = true;\n\t\n\tjindo.$Fn(function(){\n\t\tgetGNB();\n\t}).attach(window, "load");\n\t\n\tjindo.$Fn(function(oEvent){ var welSource = jindo.$Element(oEvent.element);\n\t\t\tif (!welSource.isChildOf(jindo.$Element("gnb"))) {\n\t\t\t\tgnbAllLayerClose();\n\t\t\t}\n\t}).attach(document, \'click\');\n</script>\n <!-- skip navigation -->\n<div id="u_skip">\n         <a href="#header" onclick="document.getElementById(\'header\').tabIndex=-1;document.getElementById(\'header\').focus();return false;"><span>메인 메뉴로 바로가기</span></a>\n         <a href="#content" id="gnb_goContent" onclick="document.getElementById(\'content\').tabIndex=-1;document.getElementById(\'content\').focus();return false;"><span>본문으로 바로가기</span></a>\n</div>\n<!-- //skip navigation -->\n<div class="gnb_container">\n\t<div class="gnb_content">\n\t\t<div class="gnb_box">\n\t\t\t<div class="gnb_wrap">\n\t\t\t\t<div id="gnb">\n\t\t\t\t    <script type="text/javascript" charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn"></script>\n\t\t\t\t</div>\n\t\t\t</div>\n\t\t\t<!-- 검색창 -->\n\t\t\t<form id="jSearchForm" action="/movie/search/result.naver" method="get" style="margin:0;display:none;">\n\t\t\t\t<input type="text" name="query" maxlength="100" title="영화검색" />\n\t\t\t\t<input type="hidden" name="section" value="all"/>\n\t\t\t\t<input type="hidden" name="ie" value="utf8"/>\n\t\t\t</form>\n\t\t\t<fieldset id="jSearchArea" class="srch_area">\n\t ...

# %%
soup = BeautifulSoup(res.text, "lxml")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="ko">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="no" http-equiv="imagetoolbar"/>\n  <title>\n   범죄도시2 : 네이버 영화\n  </title>\n  <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="me2:image"/>\n  <meta content="네이버영화 범죄도시2" property="me2:post_tag"/>\n  <meta content="네이버영화" property="me2:category1"/>\n  <meta content="범죄도시2" property="me2:category2"/>\n  <meta content="범죄도시2" property="og:title"/>\n  <meta content="article" property="og:type"/>\n  <meta content="https://movie.naver.com/movie/bi/mi/review.naver?code=192608" property="og:url"/>\n  <meta content="https://movie-phinf.pstatic.net/20220516_144/1652665409592Chvey_JPEG/movie_image.jpg?type=m665_443_2" property="og:image"/>\n  <meta content="가리봉동 소탕작전 후 4년 뒤,금천서 강력반은 베트남으로 도주한 용의자를 인도받아 오라는 미션을 받..." property="og:description"/>\n  <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>\n  <meta content="네이버 영화" property="og:article:author"/>\n  <meta content="https://movie.naver.com/" property="og:article:author:url"/>\n  <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>\n  <link href="/css/deploy/movie.all.css?20220613155138" rel="stylesheet" type="text/css"/>\n  <script src="/js/deploy/movie.all.js?20220613155138" type="text/javascript">\n  </script>\n </head>\n <body>\n  <div class="basic" id="wrap">\n   <!-- GNB -->\n   <script type="text/javascript">\n    function delayed_submit(object) {\n\tif (navigator.userAgent.indexOf(\'MSIE\') == -1) {\n\t\tvar b = c = new Date();\n      \twhile ((b.getTime() - c.getTime()) < 100) {\n\t\t\tb = new Date();\n      \t}\n\t} \n}\n   </script>\n   <script type="text/javascript">\n    var gnb_service = "movie";\n\tvar gnb_logout = "https://movie.naver.com/movie/bi/mi/review.naver%3Fcode%3D192608";\n\tvar gnb_template = "gnb_utf8";\n\tvar gnb_brightness=3;\n\tvar gnb_response = true;\n\t\n\tjindo.$Fn(function(){\n\t\tgetGNB();\n\t}).attach(window, "load");\n\t\n\tjindo.$Fn(function(oEvent){ var welSource = jindo.$Element(oEvent.element);\n\t\t\tif (!welSource.isChildOf(jindo.$Element("gnb"))) {\n\t\t\t\tgnbAllLayerClose();\n\t\t\t}\n\t}).attach(document, \'click\');\n   </script>\n   <!-- skip navigation -->\n   <div id="u_skip">\n    <a href="#header" onclick="document.getElementById(\'header\').tabIndex=-1;document.getElementById(\'header\').focus();return false;">\n     <span>\n      메인 메뉴로 바로가기\n     </span>\n    </a>\n    <a href="#content" id="gnb_goContent" onclick="document.getElementById(\'content\').tabIndex=-1;document.getElementById(\'content\').focus();return false;">\n     <span>\n      본문으로 바로가기\n     </span>\n    </a>\n   </div>\n   <!-- //skip navigation -->\n   <div class="gnb_container">\n    <div class="gnb_content">\n     <div class="gnb_box">\n      <div class="gnb_wrap">\n       <div id="gnb">\n        <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn" type="text/javascript">\n        </script>\n       </div>\n      </div>\n      <!-- 검색창 -->\n      <form action="/movie/search/result.naver" id="jSearchForm" method="get" style="margin:0;display:none;">\n       <input maxlength="100" name="query" title="영화검색" type="text"/>\n       <input name="section" type="hidden" value="all"/>\n       <input name="ie" type="hidden" value="utf8"/>\n      </form>\n      <fieldset class="srch_area" id="jSearchArea">\n       <legend>\n        <span class="blind">\n         영화검색 영역\n        </span>\n       </legend>\n       <div class="srch_field_on _view">\n        <span class="ipt_srch">\n         <label for="ipt_tx_srch" id="search_placeholder">\n          영화검색\n         </label>\n         <input accesskey="s" autocomplete="off" class="ipt_tx_srch" id="ipt_tx_srch" maxlength="100" name="query" style="ime-mode:active;" typ ...

# %%
ul = soup.find("ul", class_="rvw_list_area")

# %%
ul
# Out:
# <ul class="rvw_list_area">
# <li>
# <a href="#" onclick="clickcr(this, 'rli.title', '', '', event); showReviewDetail(4807776)"><strong>[스포 x] 걱정마세요, 마동석입니다. : 범죄도시2(2022) 메가박스 회원 시사회 후기 </strong></a>
# <span class="user"><a href="#" onclick="clickcr(this, 'rli.uid', '', '', event); showReviewListByNid('4807776');">aasd****</a> <em>2022.05.12</em><em>추천 3</em></span>
# <p><a href="#" onclick="clickcr(this, 'rli.content', '', '', event); showReviewDetail(4807776);">cgv와 메가박스 모두 범죄도시2 시사회를 진행하길래 두 개 다 신청했는데 신기하게도 메가박스만 당첨이 되었다.cgv는 vip 시사였고, 메박은 일반회원까지 포함이었는데도 메박에서 당첨된 게 신기했다.하여간 그러한 결과로 대전 신세계...</a></p>
# </li>
# <li>
# <a href="#" onclick="clickcr(this, 'rli.title', '', '', event); showReviewDetail(4807763)"><strong>[범죄도시2]&lt;시사회&gt;(34번째) 아는 맛이 무서운 법!! 1편 능가할듯?!</strong></a>
# <span class="user"><a href="#" onclick="clickcr(this, 'rli.uid', '', '', event); showReviewListByNid('4807763');">acts****</a> <em>2022.05.11</em><em>추천 2</em></span>
# <p><a href="#" onclick="clickcr(this, 'rli.content', '', '', event); showReviewDetail(4807763);">20220511코엑스 메가박스 9-N-8익무 시사회4.3/5 "느낌 오지? 이 놈 잡아야 하는 거"가리봉동 소탕작전 후 4년 뒤,금천서 강력반은 베트남으로 도주한 용의자를 인도받아 오라는 미션을 받는다. 괴물형사 '마석도'(마동석)와 '전일만'(최...</a></p>
# </li>
# <li>
# <a href="#" onclick="clickcr(this, 'rli.title', '', '', event); showReviewDetail(4808165)"><strong>영화 범죄도시2 줄거리 결말 손석구 악당이지만 매력적이다</strong></a>
# <span class="user"><a href="#" onclick="clickcr(this, 'rli.uid', '', '', event); showReviewListByNid('4808165');">yuki****</a> <em>2022.05.24</em><em>추천 1</em></span>
# <p><a href="#" onclick="clickcr(this, 'rli.content', '', '', event); showReviewDetail(4808165);">영화 범죄도시2 줄거리 결말 손석구 악당이지만 매력적이다지난 주말 오랜만에 와이프랑극장에가서 영화를 보고왔습니다.코로나로 근 2년넘게 넷플릭스로지나간 영화들만 보다가최신개봉작을 보니 잼나더라구요.그럼 지금부터 영화 범죄도...</a></p>
# </li>
# <li>
# <a href="#" onclick="clickcr(this, 'rli.title', '', '', event); showReviewDetail(4808289)"><strong>영화 범죄도시2 [가족영화추천]</strong></a>
# <span class="user"><a href="#" onclick="clickcr(this, 'rli.uid', '', '', event); showReviewListByNid('4808289');">yang****</a> <em>2022.05.30</em><em>추천 1</em></span>
# <p><a href="#" onclick="clickcr(this, 'rli.content', '', '', event); showReviewDetail(4808289);">       범죄도시2      감독   이상용   출연   마동석, 손석구, 최귀화   개봉   2022.05.18. 대한민국   평점                        리뷰보기    낯선 나라를 여행 그냥 다니셨나요?해외여행 갔다가내 가족이 당할 수 있는 범죄!이 영...</a></p>
# </li>
# <li>
# <a href="#" onclick="clickcr(this, 'rli.title', '', '', event); showReviewDetail(4807781)"><strong>범죄도시2 ( 전편이 누군지 몰랐다면 이번에는 너무 잘 안다 )-평점 5점</strong></a>
# <span class="user"><a href="#" onclick="clickcr(this, 'rli.uid', '', '', event); showReviewListByNid('4807781');">reno****</a> <em>2022.05.12</em><em>추천 1</em></span>
# <p><a href="#" onclick="clickcr(this, 'rli.content', '', '', event); showReviewDetail(4807781);">       범죄도시2      감독   이상용   출연   마동석, 손석구, 최귀화   개봉   2022.05.18. 대한민국      리뷰보기    마블리를 길가메시로 데뷔하게 만든 마블리 아니 마요미, 아니아니 마석도 형사가 돌아왔다. 전편만한 속편은 힘...</a></p>
# </li>
# <li>
# <a href="#" onclick="clickcr(this, 'rli.title', '', '', event); showReviewDetail(4807319)"><strong>[개봉예정] 범죄도시2 (the roundup, 2022)</strong></a>
# <span class="user"><a href="#" onclick="clickcr(this, 'rli.uid', '', '', event); showReviewListByNid('4807319');">sakg****</a> <em>2022.04.29</em><em>추천 0</em></span>
# <p><a href="#" onclick="clickcr(this, 'rli.content', '', '', event); showReviewDetail(4807319);">5월 18일 개봉예정인 영화 '범죄도시2'입니다.2017년 개봉했었던 영화 '범죄도시'의 후속편인데요..당시 '범죄도시'는 688만명을 모으며 흥행했고..'마동석','윤계상' 두 배우의 '활약'뿐만 아니라.'진선규','허성태','박지환'등 샛별 빌...</a></p>
# </li>
# <li>
# <a href="#" onclick="clickcr(this, 'rli.title', '', '', event); showReviewDetail(4807843)"><strong>[영화감상] 범죄도시2 (The Roundup , 2022)</strong></a>
# <span class="user"><a href="#" onclick="clickcr(this, 'rli.uid', '', '', event); showReviewListByNid('4807843');">sakg****</a> <em>2022.05.14</em><em>추천 0</em></span>
# <p><a href="#" onclick="clickcr(this, 'rli.content', '', '', event); showReviewDetail(4807843);"> 5월 18일 개봉되는 영화 '범죄도시2'입니다.주말에 '프리미엄 상영회'가 있어서, 먼저 만나보게 되었는데요.기대했던만큼 완전 대박이였던 ㅋㅋㅋ'마동석'의 '사이다 액션', 이번에도 최고입니다...거기다 '유머'까지..빵빵...그런데 이...</a></p>
# </li>
# <li>
# <a href="#" onclick="clickcr(this, 'rli.title', '', '', event); showReviewDetail(4808002)"><strong>범죄도시 2 마동석, 범죄와의 전쟁 출연부터 범죄도시 1, 이터널스 모습보면 마동석 근육은 괜찮은걸까?</strong></a>
# <span class="user"><a href="#" onclick="clickcr(this, 'rli.uid', '', '', event); showReviewListByNid('4808002');">ewri****</a> <em>2022.05.19</em><em>추천 0</em></span>
# <p><a href="#" onclick="clickcr(this, 'rli.content', '', '', event); showReviewDetail(4808002);">범죄도시 2, 마동석의 활약이 대단하다는 소문이 그치질 않습니다.범죄도시1 편보다 낫다, 마동석 대단하다! 속이 다 시원하다! 액션이 볼만하다!범죄도시 2 예매율이 치솟고, 관람평점이 상위를 기록합니다.이번 범죄도시 2는 마동석의 ...</a></p>
# </li>
# <li>
# <a href="#" onclick="clickcr(this, 'rli.title', '', '', event); showReviewDetail(4808094)"><strong>&lt;범죄도시 2&gt; 나쁜 놈은 맞아야지 </strong></a>
# <span class="user"><a href="#" onclick="clickcr(this, 'rli.uid', '', '', event); showReviewListByNid('4808094');">jime****</a> <em>2022.05.22</em><em>추천 0</em></span>
# <p><a href="#" onclick="clickcr(this, 'rli.content', '', '', event); showReviewDetail(4808094);">       범죄도시2      감독   이상용   출연   마동석, 손석구, 최귀화   개봉   2022.05.18. 대한민국   평점                        리뷰보기     9.6  원래 베트남 여행을 다녀온 뒤에 보려고 했다가 영화에서 베트남이 나온다기에 ...</a></p>
# </li>
# <li>
# <a href="#" onclick="clickcr(this, 'rli.title', '', '', event); showReviewDetail(4808110)"><strong>[MMR MORNING의 영화 리뷰] 범죄도시 2</strong></a>
# <span class="user"><a href="#" onclick="clickcr(this, 'rli.uid', '', '', event); showReviewListByNid('4808110');">ehgn****</a> <em>2022.05.22</em><em>추천 0</em></span>
# <p><a href="#" onclick="clickcr(this, 'rli.content', '', '', event); showReviewDetail(4808110);">       범죄도시2      감독   이상용   출연   마동석, 손석구, 최귀화   개봉   2022.05.18. 한국   평점                        리뷰보기       모하~안녕하세요 MMR MORNING aka 아이노 키츠네입니다.오늘 제가 리뷰할 영화는 바로 ...</a></p>
# </li>
# </ul>

# %%
lis = ul.find_all("li")

# %%
len(lis)
# Out:
# 10

# %%
i=0
for li in lis:
    i=i+1
    print("[%d] %s" %(i, li.a.text))
# Out:
# [1] [스포 x] 걱정마세요, 마동석입니다. : 범죄도시2(2022) 메가박스 회원 시사회 후기
# [2] [범죄도시2]<시사회>(34번째) 아는 맛이 무서운 법!! 1편 능가할듯?!
# [3] 영화 범죄도시2 줄거리 결말 손석구 악당이지만 매력적이다
# [4] 영화 범죄도시2 [가족영화추천]
# [5] 범죄도시2 ( 전편이 누군지 몰랐다면 이번에는 너무 잘 안다 )-평점 5점
# [6] [개봉예정] 범죄도시2 (the roundup, 2022)
# [7] [영화감상] 범죄도시2 (The Roundup , 2022)
# [8] 범죄도시 2 마동석, 범죄와의 전쟁 출연부터 범죄도시 1, 이터널스 모습보면 마동석 근육은 괜찮은걸까?
# [9] <범죄도시 2> 나쁜 놈은 맞아야지
# [10] [MMR MORNING의 영화 리뷰] 범죄도시 2
